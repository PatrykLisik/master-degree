# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
a, b = -5, 1

# %%
def func(x):
    return -x ** 2 + 5 * x + 10

# %%
x = np.linspace(a, b, 10 ** 4)
y = func(x)


fig, ax = plt.subplots()
ax.plot(x, y, label="Function", color="blue")

# ax.set_aspect('equal')
ax.grid(True, which='both')
fig.set_size_inches(16, 9)
fig.set_dpi(200)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.set_title(f"Fucntion in [{a},{b}]")
ax.legend()

# %%
max_iter = 1000
epsilon = 10 ** (-7)

x0=0
x1=b
for i in range(max_iter):
    new_x=(func(x1)*x0-func(x0)*x1)/(func(x1)-func(x0))
    x0=x1
    x1=new_x
    print(f"Iteration {i:<4} | x1={x1:<20} | f(x1)={func(x1)}")
    
    if np.abs(func(x1)) <= epsilon:
        print("func(x)<=epsilon")
        break
# Out:
# Iteration 0    | x1=-2.5                 | f(x1)=-8.75
# Iteration 1    | x1=-1.1538461538461537  | f(x1)=2.8994082840236697
# Iteration 2    | x1=-1.4888888888888887  | f(x1)=0.3387654320987661
# Iteration 3    | x1=-1.5332140460747035  | f(x1)=-0.01681554145427988
# Iteration 4    | x1=-1.5311178947798865  | f(x1)=8.851838537538015e-05
# Iteration 5    | x1=-1.5311288713103697  | f(x1)=2.2887984840735953e-08
# func(x)<=epsilon
