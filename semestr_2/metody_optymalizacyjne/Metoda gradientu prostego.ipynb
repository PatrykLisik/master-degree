# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
# %matplotlib widget
x = np.linspace(-4,4,4096)
y = np.linspace(-4,4,4096)
X, Y = np.meshgrid(x, y)
Z = (-3*Y-X**2)*np.exp(-Y**2-X**2) 

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.set_size_inches(5, 4)
# fig.set_dpi(200)
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# https://www.wolframalpha.com/input?i=nabla%28%28-3y-x%5E2%29*exp%28-y%5E2-x%5E2%29%29A
# ![image.png](attachment:image.png)

# %%
def gradient(x,y):
    return (x*np.exp(-x**2-y**2)*(x**2+3*y-1)), np.exp(-x**2-y**2)*(2*x**2*y+6*y**2-3)

# %%
def func(X,Y):
    return (-3*Y-X**2)*np.exp(-Y**2-X**2)

# %%
def alpha(iter:int):
    if iter in range(0, 10**4):
        return 0.05
    return 10**(-4)

# %%
start_point = np.array([-1.87,0.53])
max_iter_count = 10**5
epsilon= 10**(-7)

# %%
current_point = start_point.copy()
for iter in range(max_iter_count):
    dx,dy=gradient(current_point[0],current_point[1])
    if np.abs(dx)<=epsilon and np.abs(dy) <=epsilon:
        print(f"STOP | Iter {iter:<4} | dx={dx:<20} | dy={dy:<20}| dx<=epsilon and dy <=epsilon")
        break
    current_point-=alpha(iter)*np.array([dx,dy])
    print(f"Iter {iter:<4} | alpha: {alpha(iter):<5} | x={current_point[0]:<25} | y={current_point[1]:<20} | z={str(func(current_point[0],current_point[1])):<12}")
# Out:
# Iter 0    | alpha: 0.05  | x=-1.8612596680215308       | y=0.5272642640126745   | z=-0.1195903192421526
# Iter 1    | alpha: 0.05  | x=-1.8523357959152003       | y=0.5245136407886304   | z=-0.12296110138176887
# Iter 2    | alpha: 0.05  | x=-1.8432230520305422       | y=0.5217495403177149   | z=-0.12647130215629315
# Iter 3    | alpha: 0.05  | x=-1.8339159709313315       | y=0.5189735467377888   | z=-0.1301277566987214
# Iter 4    | alpha: 0.05  | x=-1.8244089568592454       | y=0.5161874342408318   | z=-0.1339376333079735
# Iter 5    | alpha: 0.05  | x=-1.8146962884293971       | y=0.5133931841910168   | z=-0.13790844344745043
# Iter 6    | alpha: 0.05  | x=-1.8047721247229611       | y=0.5105930035043317   | z=-0.14204805074016866
# Iter 7    | alpha: 0.05  | x=-1.7946305129565638       | y=0.507789344330943    | z=-0.14636467867218317
# Iter 8    | alpha: 0.05  | x=-1.784265397922561        | y=0.504984925069949    | z=-0.1508669166744738
# ...

# %%
current_point[0]
# Out:
# -1.4398182765216394e-07
